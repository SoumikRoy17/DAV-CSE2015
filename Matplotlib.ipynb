# %% [markdown]
# <a href="https://colab.research.google.com/github/SoumikRoy17/DAV-CSE2015/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])
plt.plot(xpoints, ypoints)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = "*")
plt.show ()

# %% [markdown]
# ypoints = np.array([3, 8, 1, 10])
# plt.plot(ypoints, marker = "^")
# plt.show ()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = "o", ms = 20)
plt.show ()

# %%
xpoints = np.array([2,4, 6, 8])
ypoints = np.array([3, 8, 1, 10])
plt.plot(xpoints, ypoints, marker = "o", ms = 5, linestyle = 'dotted')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints = np.array([80,85,90,95,100,105,110,115,120,125])
ypoints = np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(xpoints, ypoints)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title("Sports watch data")
plt.grid()
plt.show()

# %%
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.grid()
plt.plot(x,y,color = 'r',marker="*")
x = np.array([0,1,2,3])
y = np.array([6,2,7,11])
plt.subplot(1,2,2)
plt.plot(x,y,color ='g',marker="^")
plt.grid()
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors, s=10)
plt.show()

# %%
section = ['A','B','C','D']
Student = [10,20,30,2]
plt.bar(section,Student)
plt.show()

# %%
x=[10,20,30,40,50]
l=['apples','bananas','cherries','oranges','mangoes']
plt.pie(x,labels=l)
plt.show()

# %%
x=[10,20,30,40,50]
l=['apples','bananas','cherries','oranges','mangoes']
Ex = [0.0,0.0,0.0,0.0,0.2]
plt.pie(x,labels=l , explode=Ex)
plt.show()

# %%
x=[1,2,2,3,4,4,5,5]
plt.hist(x)
plt.show()

# %%
section = ['a','b','c']
student = [10,20,30]
marks=[10,20,20,30,40,40]
plt.subplot(2,2,1)
plt.bar(section,student)
plt.subplot(2,2,2)
plt.pie(student)
plt.subplot(2,2,3)
plt.hist(marks)
plt.subplot(2,2,4)
plt.plot([1,2,3],[4,5,6])
plt.show()

# %%
import pandas as pd
data = pd.DataFrame(np.random.rand(10,10))
plt.figure(figsize=(8,6))
plt.contour(data.values)
plt.show()

# %%
import seaborn as sns
data = np.random.random((5,17))
plt.imshow(data)
plt.title("2-D Heat Map")
plt.colorbar()
plt.show()

# %%
data = np.random.randint(low = 14, high= 100, size =(10,10))
hm = sns.heatmap(data = data, annot = True, cmap = "cividis")
plt.show()
